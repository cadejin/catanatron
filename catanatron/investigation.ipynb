# %%
import torch
from sft_eval import PolicyNet  # or import your model definition

checkpoint = torch.load("policy_sft.pt")

input_dim = checkpoint["input_dim"]
num_actions = checkpoint["num_actions"]
idx2action = checkpoint["idx2action"]

model = PolicyNet(input_dim, num_actions)
model.load_state_dict(checkpoint["state_dict"])
model.eval()
# Out:
# PolicyNet(
#   (net): Sequential(
#     (0): Linear(in_features=6, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=521, bias=True)
#   )
# )

# %%
for name, param in model.named_parameters():
    print(name, param.shape)
# Out:
# net.0.weight torch.Size([256, 6])
# net.0.bias torch.Size([256])
# net.2.weight torch.Size([256, 256])
# net.2.bias torch.Size([256])
# net.4.weight torch.Size([521, 256])
# net.4.bias torch.Size([521])

# %%
import pandas as pd

w = model.net[0].weight.detach().numpy()
df = pd.DataFrame(w, columns=["BRICK","WOOD","SHEEP","WHEAT","ORE","VP"])
print(df.head())
# Out:
#       BRICK      WOOD     SHEEP     WHEAT       ORE        VP
# 0  0.352846  0.390151 -0.138592  0.482652 -0.134897  0.107915
# 1 -0.281113  0.288690  0.431545 -0.318852  0.396663  0.094861
# 2  0.330936  0.092001  0.239117 -0.060689  0.345641  0.062946
# 3 -0.142741  0.047987 -0.310156  0.016095 -0.155314  0.324403
# 4 -0.322259 -0.188207 -0.115279 -0.245468  0.038532 -0.403218

# %%
final_w = model.net[-1].weight.detach().numpy()
final_b = model.net[-1].bias.detach().numpy()

# %%
import numpy as np

first = model.net[0].weight.detach().numpy()  # shape (256, 6)
second = model.net[2].weight.detach().numpy() # shape (256, 256)
final = model.net[4].weight.detach().numpy()  # shape (num_actions, 256)

# multiply absolute weights through network
importance = np.abs(final) @ np.abs(second) @ np.abs(first)

print("Importance shape:", importance.shape)
# Out:
# Importance shape: (521, 6)

# %%
len(idx2action)
# Out:
# 521

# %%
for i, act in enumerate(idx2action):
    print(f"\nAction: {act}")
    sorted_idx = np.argsort(-importance[i])
    for j in sorted_idx:
        print(f"  {['BRICK','WOOD','SHEEP','WHEAT','ORE','VP'][j]}: {importance[i][j]:.4f}")
# Out:
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=50)")
#   WOOD: 46.2041
#   WHEAT: 45.7152
#   BRICK: 43.4060
#   ORE: 43.0001
#   SHEEP: 42.7056
#   VP: 33.6435
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(49, 50))")
#   WOOD: 49.3756
#   WHEAT: 49.0783
#   ORE: 46.2981
#   BRICK: 46.1651
#   SHEEP: 45.6969
#   VP: 36.1307
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=47)")
#   WOOD: 44.2020
#   WHEAT: 43.9649
#   BRICK: 41.5528
#   ORE: 41.2516
#   SHEEP: 40.8789
#   VP: 32.2332
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(45, 47))")
#   WOOD: 47.1575
#   WHEAT: 47.0575
#   BRICK: 44.4414
#   ORE: 44.2139
#   SHEEP: 43.8866
#   VP: 34.4324
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=21)")
#   WOOD: 49.3503
#   WHEAT: 49.2905
#   BRICK: 46.5147
#   ORE: 46.3593
#   SHEEP: 45.9926
#   VP: 36.1001
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(21, 43))")
#   WHEAT: 40.9659
#   WOOD: 40.7898
#   BRICK: 38.2696
#   ORE: 38.0610
#   SHEEP: 37.6835
#   VP: 29.8061
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=41)")
#   WOOD: 48.5779
#   WHEAT: 48.5692
#   BRICK: 45.6954
#   ORE: 45.5972
#   SHEEP: 45.2415
#   VP: 35.5185
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(39, 41))")
#   WHEAT: 46.5981
#   WOOD: 46.4230
#   BRICK: 43.7650
#   ORE: 43.7163
#   SHEEP: 43.5152
#   VP: 34.0947
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.ROLL: 'ROLL'>, value=None)")
#   WOOD: 32.5427
#   WHEAT: 32.4780
#   BRICK: 30.9357
#   ORE: 30.2850
#   SHEEP: 30.2819
#   VP: 23.8397
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 0, 2), None, None))")
#   WOOD: 30.3069
#   WHEAT: 30.1241
#   BRICK: 28.6700
#   SHEEP: 28.3850
#   ORE: 28.3264
#   VP: 22.2028
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None)")
#   WHEAT: 34.6029
#   WOOD: 34.5490
#   BRICK: 32.8298
#   ORE: 32.2815
#   SHEEP: 32.2796
#   VP: 25.3503
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=None)")
#   WHEAT: 32.4010
#   WOOD: 32.3692
#   BRICK: 30.6916
#   ORE: 30.5475
#   SHEEP: 30.3670
#   VP: 23.6558
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None)")
#   WOOD: 32.9379
#   WHEAT: 32.8249
#   BRICK: 31.1504
#   ORE: 30.8496
#   SHEEP: 30.7559
#   VP: 23.9784
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'SHEEP'))")
#   WOOD: 43.2922
#   WHEAT: 43.2196
#   BRICK: 40.6953
#   ORE: 40.3795
#   SHEEP: 40.0616
#   VP: 31.4227
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', None, 'WHEAT'))")
#   WOOD: 43.8246
#   WHEAT: 43.7971
#   BRICK: 41.4202
#   ORE: 40.9290
#   SHEEP: 40.6347
#   VP: 31.8581
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'BRICK'))")
#   WOOD: 46.6931
#   WHEAT: 46.4768
#   BRICK: 44.1852
#   SHEEP: 43.8453
#   ORE: 43.6341
#   VP: 33.9887
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value=None)")
#   WHEAT: 33.2089
#   WOOD: 33.0018
#   BRICK: 31.2145
#   ORE: 31.1433
#   SHEEP: 30.9182
#   VP: 24.2266
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.PLAY_MONOPOLY: 'PLAY_MONOPOLY'>, value='BRICK')")
#   WHEAT: 38.3371
#   WOOD: 38.1585
#   ORE: 36.3458
#   BRICK: 36.2253
#   SHEEP: 35.9411
#   VP: 28.4693
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 0, 0), None, None))")
#   WHEAT: 39.6233
#   WOOD: 39.4572
#   BRICK: 37.4297
#   ORE: 37.0381
#   SHEEP: 36.7486
#   VP: 29.0664
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -2, 0), None, None))")
#   WHEAT: 37.5482
#   WOOD: 37.2105
#   BRICK: 35.1283
#   ORE: 34.9078
#   SHEEP: 34.6204
#   VP: 27.4445
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(19, 21))")
#   WHEAT: 45.7361
#   WOOD: 45.4678
#   ORE: 43.3162
#   BRICK: 42.7637
#   SHEEP: 42.5910
#   VP: 33.4970
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -2, 0), None, None))")
#   WHEAT: 44.9072
#   WOOD: 44.6935
#   BRICK: 42.3169
#   ORE: 41.6743
#   SHEEP: 41.5710
#   VP: 32.7818
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 2, 0), None, None))")
#   WHEAT: 39.8142
#   WOOD: 39.6809
#   ORE: 37.2905
#   BRICK: 36.9343
#   SHEEP: 36.7555
#   VP: 28.9409
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 1, 0), None, None))")
#   WHEAT: 34.1343
#   WOOD: 33.6649
#   BRICK: 31.8923
#   ORE: 31.7366
#   SHEEP: 31.4253
#   VP: 25.0886
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'WHEAT'))")
#   WHEAT: 43.9175
#   WOOD: 43.7280
#   BRICK: 41.2351
#   ORE: 41.0238
#   SHEEP: 40.9480
#   VP: 32.0190
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'WOOD'))")
#   WOOD: 42.5734
#   WHEAT: 42.5068
#   BRICK: 40.2046
#   ORE: 39.8192
#   SHEEP: 39.5446
#   VP: 30.9606
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, 0, -2), <Color.RED: 'RED'>, None))")
#   WOOD: 41.1770
#   WHEAT: 41.0904
#   BRICK: 38.4959
#   ORE: 38.2492
#   SHEEP: 37.8876
#   VP: 29.9675
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'BRICK'))")
#   WOOD: 43.1035
#   WHEAT: 43.0474
#   BRICK: 40.6748
#   ORE: 40.1480
#   SHEEP: 39.9699
#   VP: 31.3798
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None)")
#   WHEAT: 34.9762
#   WOOD: 34.8101
#   BRICK: 33.3361
#   ORE: 32.8260
#   SHEEP: 32.6918
#   VP: 25.7071
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 2, 0), <Color.RED: 'RED'>, None))")
#   WHEAT: 40.3136
#   WOOD: 39.7057
#   BRICK: 37.4272
#   ORE: 37.2431
#   SHEEP: 37.2283
#   VP: 29.3529
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(43, 47))")
#   WHEAT: 40.8686
#   WOOD: 40.4233
#   BRICK: 38.1433
#   ORE: 37.9097
#   SHEEP: 37.6525
#   VP: 29.7491
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, 0, -2), None, None))")
#   WHEAT: 37.8225
#   WOOD: 37.7477
#   BRICK: 35.1811
#   ORE: 35.0916
#   SHEEP: 34.7409
#   VP: 27.4112
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -1, 0), None, None))")
#   WHEAT: 38.7018
#   WOOD: 38.2586
#   ORE: 36.1002
#   BRICK: 36.0589
#   SHEEP: 35.6742
#   VP: 28.1772
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, -1, 2), None, None))")
#   WHEAT: 32.0916
#   WOOD: 31.6579
#   BRICK: 29.9279
#   ORE: 29.7612
#   SHEEP: 29.5841
#   VP: 23.4456
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', None, 'WOOD'))")
#   WOOD: 51.7321
#   WHEAT: 51.2438
#   BRICK: 48.4971
#   ORE: 47.8010
#   SHEEP: 47.6667
#   VP: 37.2747
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', None, 'BRICK'))")
#   WOOD: 44.4516
#   WHEAT: 44.4267
#   BRICK: 41.8403
#   SHEEP: 41.3953
#   ORE: 41.3436
#   VP: 32.4124
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(19, 46))")
#   WHEAT: 46.8360
#   WOOD: 46.1399
#   ORE: 44.0101
#   SHEEP: 43.7251
#   BRICK: 43.6064
#   VP: 34.2897
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 1, 1), None, None))")
#   WHEAT: 31.5255
#   WOOD: 31.4861
#   ORE: 29.9995
#   BRICK: 29.7611
#   SHEEP: 29.5098
#   VP: 23.2609
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'SHEEP'))")
#   WHEAT: 43.6105
#   WOOD: 43.4934
#   BRICK: 41.0743
#   ORE: 40.9294
#   SHEEP: 40.5746
#   VP: 31.8211
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', None, 'WOOD'))")
#   WHEAT: 48.8466
#   WOOD: 48.6218
#   BRICK: 45.7577
#   ORE: 45.3413
#   SHEEP: 44.9766
#   VP: 35.4762
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 0, 1), None, None))")
#   WHEAT: 33.9343
#   WOOD: 33.6974
#   BRICK: 32.2551
#   SHEEP: 31.7390
#   ORE: 31.7378
#   VP: 25.0046
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 0, -1), None, None))")
#   WHEAT: 33.3597
#   WOOD: 33.2517
#   BRICK: 31.5728
#   ORE: 31.2323
#   SHEEP: 31.0286
#   VP: 24.4851
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -2, 2), None, None))")
#   WOOD: 38.0999
#   WHEAT: 37.8057
#   BRICK: 35.7738
#   ORE: 35.6120
#   SHEEP: 35.2244
#   VP: 27.6438
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 2, -1), <Color.WHITE: 'WHITE'>, None))")
#   WHEAT: 36.6436
#   WOOD: 36.6412
#   BRICK: 34.3659
#   ORE: 34.1505
#   SHEEP: 33.8648
#   VP: 26.8913
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', None, 'BRICK'))")
#   WOOD: 49.5067
#   WHEAT: 49.4812
#   BRICK: 46.6527
#   ORE: 46.5283
#   SHEEP: 46.2942
#   VP: 36.3504
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(46, 48))")
#   WHEAT: 49.2476
#   WOOD: 48.7782
#   BRICK: 46.0272
#   ORE: 45.8896
#   SHEEP: 45.6077
#   VP: 35.6640
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 2, -1), None, None))")
#   WHEAT: 42.0098
#   WOOD: 41.4976
#   BRICK: 39.1226
#   ORE: 38.9073
#   SHEEP: 38.7610
#   VP: 30.5860
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 1, 0), None, None))")
#   WOOD: 38.0723
#   WHEAT: 37.7630
#   BRICK: 35.6406
#   ORE: 35.4936
#   SHEEP: 35.2209
#   VP: 27.6151
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 0, 2), None, None))")
#   WHEAT: 41.4606
#   WOOD: 41.2017
#   BRICK: 38.8233
#   ORE: 38.5800
#   SHEEP: 38.2566
#   VP: 30.2375
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 1, -1), None, None))")
#   WHEAT: 36.2775
#   WOOD: 35.9283
#   BRICK: 34.0576
#   ORE: 33.7857
#   SHEEP: 33.6345
#   VP: 26.4546
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 1, -2), None, None))")
#   WOOD: 45.2352
#   WHEAT: 45.2038
#   BRICK: 42.3033
#   ORE: 41.9441
#   SHEEP: 41.6567
#   VP: 32.8326
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 1, 1), None, None))")
#   WHEAT: 30.8430
#   WOOD: 30.7273
#   BRICK: 29.1291
#   ORE: 28.8748
#   SHEEP: 28.6532
#   VP: 22.7751
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -1, -1), None, None))")
#   WOOD: 32.5918
#   WHEAT: 32.4213
#   ORE: 30.6172
#   BRICK: 30.6121
#   SHEEP: 30.3638
#   VP: 23.7763
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'WHEAT'))")
#   WOOD: 41.9394
#   WHEAT: 41.6578
#   BRICK: 39.5964
#   ORE: 39.1544
#   SHEEP: 39.1012
#   VP: 30.4349
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'ORE'))")
#   WOOD: 44.3737
#   WHEAT: 43.9805
#   BRICK: 42.0521
#   ORE: 41.8157
#   SHEEP: 41.4407
#   VP: 32.1701
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(38, 39))")
#   WHEAT: 43.5511
#   WOOD: 42.8995
#   ORE: 40.8063
#   SHEEP: 40.7186
#   BRICK: 40.5164
#   VP: 31.8689
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 1, -2), None, None))")
#   WHEAT: 31.0892
#   WOOD: 30.7339
#   BRICK: 29.1997
#   ORE: 28.9535
#   SHEEP: 28.7397
#   VP: 22.8789
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', None, 'SHEEP'))")
#   WHEAT: 44.5255
#   WOOD: 44.4317
#   BRICK: 41.6441
#   ORE: 41.4312
#   SHEEP: 41.1687
#   VP: 32.4163
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -2, 1), None, None))")
#   WHEAT: 32.6977
#   WOOD: 32.4080
#   BRICK: 30.8523
#   ORE: 30.4471
#   SHEEP: 30.3533
#   VP: 24.0111
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 2, 0), None, None))")
#   WHEAT: 30.8392
#   WOOD: 30.5643
#   BRICK: 28.8977
#   ORE: 28.7127
#   SHEEP: 28.5060
#   VP: 22.6315
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -1, 1), None, None))")
#   WOOD: 33.3408
#   WHEAT: 33.0941
#   BRICK: 31.6068
#   ORE: 31.2097
#   SHEEP: 31.0340
#   VP: 24.2403
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -1, -1), None, None))")
#   WHEAT: 37.8572
#   WOOD: 37.6125
#   BRICK: 35.3991
#   ORE: 35.1957
#   SHEEP: 34.9357
#   VP: 27.5909
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -2, 1), None, None))")
#   WOOD: 30.1337
#   WHEAT: 29.7705
#   ORE: 28.3946
#   BRICK: 28.2156
#   SHEEP: 28.0203
#   VP: 21.8914
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', None, 'WHEAT'))")
#   WOOD: 50.6794
#   WHEAT: 50.2173
#   BRICK: 47.6287
#   ORE: 47.3083
#   SHEEP: 46.9202
#   VP: 36.8765
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 2, -2), <Color.WHITE: 'WHITE'>, None))")
#   WHEAT: 32.2504
#   WOOD: 32.1100
#   BRICK: 30.3043
#   ORE: 30.1700
#   SHEEP: 30.0655
#   VP: 23.7851
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 1, -1), <Color.WHITE: 'WHITE'>, None))")
#   WOOD: 32.6170
#   WHEAT: 32.3789
#   BRICK: 30.3961
#   ORE: 30.3216
#   SHEEP: 30.0168
#   VP: 23.6703
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value=None)")
#   WOOD: 34.5872
#   WHEAT: 34.4928
#   BRICK: 32.7421
#   ORE: 32.3718
#   SHEEP: 32.3336
#   VP: 25.2247
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None)")
#   WHEAT: 38.9188
#   WOOD: 38.3663
#   BRICK: 36.1013
#   ORE: 35.9934
#   SHEEP: 35.7455
#   VP: 28.3226
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', None, 'ORE'))")
#   WOOD: 51.2334
#   WHEAT: 50.7704
#   ORE: 47.8908
#   BRICK: 47.7345
#   SHEEP: 47.2046
#   VP: 37.0647
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.DISCARD: 'DISCARD'>, value=None)")
#   WOOD: 31.1303
#   WHEAT: 31.0539
#   BRICK: 29.4386
#   ORE: 29.0777
#   SHEEP: 29.0258
#   VP: 22.6467
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(16, 21))")
#   WHEAT: 45.9114
#   WOOD: 45.6817
#   ORE: 42.7663
#   BRICK: 42.7015
#   SHEEP: 42.2488
#   VP: 33.1876
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(16, 18))")
#   WHEAT: 47.9266
#   WOOD: 47.9086
#   ORE: 45.1579
#   BRICK: 44.8946
#   SHEEP: 44.4583
#   VP: 34.8397
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(18, 40))")
#   WHEAT: 48.0047
#   WOOD: 47.8051
#   ORE: 45.1821
#   BRICK: 45.0493
#   SHEEP: 44.9581
#   VP: 35.1735
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -1, 0), None, None))")
#   WHEAT: 39.2749
#   WOOD: 39.0734
#   ORE: 36.9412
#   BRICK: 36.7519
#   SHEEP: 36.3779
#   VP: 28.7850
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 0, -1), None, None))")
#   WOOD: 31.9926
#   WHEAT: 31.8158
#   BRICK: 30.2315
#   ORE: 29.9465
#   SHEEP: 29.8234
#   VP: 23.4241
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 0, 0), None, None))")
#   WHEAT: 33.4959
#   WOOD: 33.4450
#   BRICK: 31.4523
#   ORE: 31.1900
#   SHEEP: 30.9809
#   VP: 24.5975
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(40, 42))")
#   WHEAT: 47.1506
#   WOOD: 46.7696
#   ORE: 44.2403
#   BRICK: 44.0227
#   SHEEP: 44.0152
#   VP: 34.4025
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'ORE'))")
#   WOOD: 45.9022
#   WHEAT: 45.8726
#   BRICK: 43.4857
#   ORE: 42.9584
#   SHEEP: 42.6404
#   VP: 33.5051
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 0, 1), None, None))")
#   WOOD: 29.9233
#   WHEAT: 29.7062
#   BRICK: 28.5270
#   ORE: 27.9721
#   SHEEP: 27.9492
#   VP: 21.9233
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(19, 20))")
#   WHEAT: 45.7808
#   WOOD: 45.5740
#   ORE: 42.8883
#   BRICK: 42.8591
#   SHEEP: 42.3893
#   VP: 33.3343
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'WOOD'))")
#   WOOD: 46.9001
#   WHEAT: 46.5745
#   BRICK: 44.3758
#   ORE: 43.7491
#   SHEEP: 43.6981
#   VP: 34.0208
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 2, -2), None, None))")
#   WHEAT: 38.3256
#   WOOD: 37.9757
#   BRICK: 35.9169
#   ORE: 35.6251
#   SHEEP: 35.3932
#   VP: 27.9557
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -2, 2), None, None))")
#   WOOD: 30.9488
#   WHEAT: 30.8356
#   BRICK: 29.1797
#   ORE: 29.0675
#   SHEEP: 28.9428
#   VP: 22.5986
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(41, 42))")
#   WHEAT: 48.6358
#   WOOD: 48.1595
#   BRICK: 45.5229
#   ORE: 45.4004
#   SHEEP: 45.1783
#   VP: 35.3389
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, -1, 2), None, None))")
#   WHEAT: 33.0683
#   WOOD: 32.7741
#   BRICK: 31.2321
#   ORE: 30.8693
#   SHEEP: 30.6966
#   VP: 24.2828
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(48, 49))")
#   WHEAT: 50.1861
#   WOOD: 49.7653
#   ORE: 47.2117
#   SHEEP: 46.9999
#   BRICK: 46.9585
#   VP: 36.5178
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(40, 44))")
#   WOOD: 47.6770
#   WHEAT: 47.6532
#   ORE: 44.8210
#   BRICK: 44.5481
#   SHEEP: 44.1821
#   VP: 34.6785
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(22, 49))")
#   WHEAT: 48.8038
#   WOOD: 48.3057
#   BRICK: 45.6344
#   ORE: 45.5590
#   SHEEP: 45.3629
#   VP: 35.4241
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=50)")
#   WHEAT: 45.0116
#   WOOD: 44.9472
#   BRICK: 42.7539
#   SHEEP: 42.3472
#   ORE: 42.1336
#   VP: 32.9029
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(17, 39))")
#   WHEAT: 52.8626
#   WOOD: 52.6141
#   ORE: 49.8212
#   BRICK: 49.5922
#   SHEEP: 49.4788
#   VP: 38.5203
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', None, 'ORE'))")
#   WHEAT: 47.3853
#   WOOD: 47.1401
#   BRICK: 44.5034
#   ORE: 44.0447
#   SHEEP: 43.9012
#   VP: 34.3351
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=46)")
#   WOOD: 40.8296
#   WHEAT: 40.7906
#   BRICK: 38.7000
#   ORE: 38.5704
#   SHEEP: 38.2872
#   VP: 29.9584
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(17, 18))")
#   WHEAT: 46.6081
#   WOOD: 46.3731
#   ORE: 43.8056
#   BRICK: 43.6676
#   SHEEP: 43.5837
#   VP: 34.1335
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(37, 38))")
#   WHEAT: 48.8844
#   WOOD: 48.5824
#   ORE: 45.8120
#   BRICK: 45.7182
#   SHEEP: 45.5922
#   VP: 35.6806
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 1, -2), <Color.WHITE: 'WHITE'>, None))")
#   WOOD: 51.6011
#   WHEAT: 51.4755
#   BRICK: 48.4057
#   ORE: 48.3480
#   SHEEP: 48.0373
#   VP: 37.5701
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -1, 1), None, None))")
#   WHEAT: 56.1406
#   WOOD: 55.9099
#   BRICK: 52.9219
#   SHEEP: 52.4536
#   ORE: 52.2496
#   VP: 40.8159
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(50, 51))")
#   WHEAT: 43.5887
#   WOOD: 43.2677
#   ORE: 40.8551
#   BRICK: 40.6092
#   SHEEP: 40.4695
#   VP: 31.8564
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=41)")
#   WHEAT: 50.0490
#   WOOD: 49.8531
#   BRICK: 47.2893
#   SHEEP: 46.6997
#   ORE: 46.5614
#   VP: 36.2704
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', None, 'ORE'))")
#   WHEAT: 49.5845
#   WOOD: 49.2439
#   BRICK: 46.5586
#   ORE: 46.4917
#   SHEEP: 45.8998
#   VP: 36.1441
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(51, 52))")
#   WHEAT: 38.8265
#   WOOD: 38.6923
#   ORE: 36.6892
#   BRICK: 36.4857
#   SHEEP: 36.2013
#   VP: 28.6320
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(36, 37))")
#   WHEAT: 46.3496
#   WOOD: 46.1724
#   BRICK: 43.8747
#   ORE: 43.7312
#   SHEEP: 43.4699
#   VP: 33.9161
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=18)")
#   WOOD: 44.9283
#   WHEAT: 44.9203
#   BRICK: 42.4660
#   ORE: 42.2579
#   SHEEP: 42.1915
#   VP: 32.8613
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', None, 'SHEEP'))")
#   WOOD: 46.8360
#   WHEAT: 46.8233
#   BRICK: 44.5784
#   SHEEP: 44.2564
#   ORE: 44.2094
#   VP: 34.4229
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=20)")
#   WOOD: 46.7516
#   WHEAT: 46.7128
#   BRICK: 44.2339
#   ORE: 44.0072
#   SHEEP: 43.9461
#   VP: 34.2759
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=18)")
#   WOOD: 50.1306
#   WHEAT: 50.1067
#   BRICK: 47.6758
#   SHEEP: 46.9944
#   ORE: 46.7566
#   VP: 36.6329
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=5)")
#   WHEAT: 36.3627
#   WOOD: 36.1681
#   BRICK: 34.5448
#   ORE: 34.1012
#   SHEEP: 33.9641
#   VP: 26.7511
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(4, 5))")
#   WHEAT: 38.6873
#   WOOD: 38.6220
#   ORE: 36.7672
#   BRICK: 36.6657
#   SHEEP: 36.4977
#   VP: 28.4869
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=10)")
#   WOOD: 43.8200
#   WHEAT: 43.7231
#   BRICK: 41.2479
#   ORE: 40.9426
#   SHEEP: 40.6334
#   VP: 32.0323
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(10, 11))")
#   WHEAT: 45.8009
#   WOOD: 45.4930
#   ORE: 43.0316
#   BRICK: 42.7909
#   SHEEP: 42.5297
#   VP: 33.4979
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=3)")
#   WOOD: 49.5326
#   WHEAT: 49.3537
#   BRICK: 46.6307
#   ORE: 46.4099
#   SHEEP: 46.0732
#   VP: 36.1814
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(3, 12))")
#   WHEAT: 37.7003
#   WOOD: 37.6361
#   BRICK: 35.4949
#   ORE: 35.2787
#   SHEEP: 34.9299
#   VP: 27.5941
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=20)")
#   WOOD: 44.4580
#   WHEAT: 44.1019
#   BRICK: 41.7469
#   ORE: 41.4313
#   SHEEP: 41.1760
#   VP: 32.3216
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(20, 22))")
#   WOOD: 32.7287
#   WHEAT: 32.5922
#   BRICK: 31.1309
#   ORE: 30.7701
#   SHEEP: 30.6428
#   VP: 24.0544
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=None)")
#   WOOD: 29.7813
#   WHEAT: 29.7384
#   BRICK: 28.2963
#   ORE: 28.0703
#   SHEEP: 28.0040
#   VP: 21.9136
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None)")
#   WHEAT: 31.5805
#   WOOD: 31.5551
#   BRICK: 29.9409
#   ORE: 29.7010
#   SHEEP: 29.6202
#   VP: 23.1716
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.ROLL: 'ROLL'>, value=None)")
#   WOOD: 27.5932
#   WHEAT: 27.5432
#   BRICK: 26.2657
#   ORE: 26.0571
#   SHEEP: 25.9728
#   VP: 20.3579
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 2, -2), None, None))")
#   WHEAT: 33.8189
#   WOOD: 33.8093
#   BRICK: 32.4417
#   SHEEP: 31.7897
#   ORE: 31.7503
#   VP: 24.9290
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.END_TURN: 'END_TURN'>, value=None)")
#   WOOD: 29.7095
#   WHEAT: 29.6802
#   BRICK: 28.2455
#   ORE: 27.9728
#   SHEEP: 27.9145
#   VP: 21.9235
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=5)")
#   WOOD: 43.4614
#   WHEAT: 43.3147
#   BRICK: 41.4725
#   SHEEP: 40.6722
#   ORE: 40.5796
#   VP: 31.4759
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.DISCARD: 'DISCARD'>, value=None)")
#   WHEAT: 32.1701
#   WOOD: 32.1642
#   BRICK: 30.5367
#   ORE: 30.2412
#   SHEEP: 30.1622
#   VP: 23.5176
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.DISCARD: 'DISCARD'>, value=None)")
#   WOOD: 36.1178
#   WHEAT: 36.0430
#   BRICK: 34.3965
#   ORE: 34.0327
#   SHEEP: 33.8837
#   VP: 26.4531
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 1, 1), None, None))")
#   WOOD: 30.3639
#   WHEAT: 30.1182
#   BRICK: 28.7916
#   ORE: 28.3203
#   SHEEP: 28.2466
#   VP: 22.1232
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUY_DEVELOPMENT_CARD: 'BUY_DEVELOPMENT_CARD'>, value=None)")
#   WOOD: 34.7944
#   WHEAT: 34.7741
#   BRICK: 33.0728
#   ORE: 32.7513
#   SHEEP: 32.7450
#   VP: 25.4232
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'WOOD'))")
#   WOOD: 37.5018
#   WHEAT: 37.3858
#   BRICK: 35.4113
#   ORE: 35.1868
#   SHEEP: 35.0326
#   VP: 27.3745
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(22, 23))")
#   WHEAT: 36.6439
#   WOOD: 36.1112
#   BRICK: 34.0322
#   ORE: 33.9974
#   SHEEP: 33.6291
#   VP: 26.6142
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -1, 1), <Color.ORANGE: 'ORANGE'>, None))")
#   WOOD: 39.2090
#   WHEAT: 38.6073
#   BRICK: 37.1825
#   ORE: 36.7065
#   SHEEP: 36.4649
#   VP: 28.3565
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.PLAY_KNIGHT_CARD: 'PLAY_KNIGHT_CARD'>, value=None)")
#   WOOD: 26.6216
#   WHEAT: 26.5591
#   ORE: 25.1833
#   BRICK: 25.1449
#   SHEEP: 24.9668
#   VP: 19.5398
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 0, 2), None, None))")
#   WHEAT: 35.3648
#   WOOD: 35.3225
#   ORE: 33.4712
#   BRICK: 33.2675
#   SHEEP: 33.0103
#   VP: 25.9941
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=23)")
#   WHEAT: 30.9265
#   WOOD: 30.8529
#   BRICK: 29.3155
#   ORE: 29.0731
#   SHEEP: 28.9040
#   VP: 22.8131
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(5, 16))")
#   WHEAT: 42.4319
#   WOOD: 42.0971
#   BRICK: 39.8063
#   ORE: 39.3710
#   SHEEP: 39.1362
#   VP: 30.7343
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -1, 0), None, None))")
#   WOOD: 36.5050
#   WHEAT: 36.3649
#   ORE: 34.5903
#   BRICK: 34.5272
#   SHEEP: 34.3625
#   VP: 26.8479
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=20)")
#   WHEAT: 41.8725
#   WOOD: 41.7940
#   BRICK: 39.9893
#   SHEEP: 39.1651
#   ORE: 39.0256
#   VP: 30.2805
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(6, 23))")
#   WHEAT: 35.4991
#   WOOD: 35.2785
#   BRICK: 33.4171
#   ORE: 33.2020
#   SHEEP: 32.8501
#   VP: 25.9418
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'WOOD'))")
#   WOOD: 50.4131
#   WHEAT: 50.1578
#   BRICK: 47.9549
#   ORE: 47.1361
#   SHEEP: 47.1323
#   VP: 36.5763
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(6, 7))")
#   WHEAT: 45.1933
#   WOOD: 44.9980
#   BRICK: 42.7237
#   SHEEP: 42.3517
#   ORE: 42.2732
#   VP: 32.9287
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=23)")
#   WOOD: 42.7456
#   WHEAT: 42.4456
#   BRICK: 40.4988
#   ORE: 39.8051
#   SHEEP: 39.7661
#   VP: 30.7411
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(7, 24))")
#   WHEAT: 45.6505
#   WOOD: 45.4096
#   BRICK: 43.1964
#   SHEEP: 42.6770
#   ORE: 42.6609
#   VP: 33.2271
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=24)")
#   WOOD: 49.0405
#   WHEAT: 48.9034
#   BRICK: 46.0814
#   ORE: 46.0215
#   SHEEP: 45.9695
#   VP: 35.5668
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 1, 0), <Color.BLUE: 'BLUE'>, None))")
#   WOOD: 37.6451
#   WHEAT: 37.3244
#   BRICK: 35.5103
#   ORE: 35.4925
#   SHEEP: 35.1717
#   VP: 27.3319
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(16, 21))")
#   WHEAT: 35.8020
#   WOOD: 35.6452
#   BRICK: 33.8560
#   SHEEP: 33.6657
#   ORE: 33.5437
#   VP: 26.2333
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=21)")
#   WOOD: 40.5383
#   WHEAT: 40.5011
#   BRICK: 38.3298
#   ORE: 38.2651
#   SHEEP: 38.1221
#   VP: 29.7985
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=15)")
#   WOOD: 46.8595
#   WHEAT: 46.4625
#   BRICK: 43.9406
#   ORE: 43.6114
#   SHEEP: 43.4114
#   VP: 34.1240
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(4, 15))")
#   WOOD: 42.9614
#   WHEAT: 42.7056
#   ORE: 40.2064
#   BRICK: 40.1465
#   SHEEP: 39.6353
#   VP: 31.3514
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=39)")
#   WOOD: 43.7297
#   WHEAT: 43.4932
#   BRICK: 41.1105
#   ORE: 40.8821
#   SHEEP: 40.4340
#   VP: 31.9139
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(17, 39))")
#   WOOD: 48.1042
#   WHEAT: 48.0229
#   BRICK: 45.2356
#   ORE: 45.0708
#   SHEEP: 44.7801
#   VP: 35.1384
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=8)")
#   WOOD: 52.4738
#   WHEAT: 52.2344
#   BRICK: 49.2750
#   ORE: 48.9787
#   SHEEP: 48.6350
#   VP: 38.1727
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(8, 27))")
#   WOOD: 45.8179
#   WHEAT: 45.4754
#   BRICK: 43.1476
#   ORE: 42.8169
#   SHEEP: 42.5636
#   VP: 33.4287
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=6)")
#   WOOD: 49.5824
#   WHEAT: 49.4797
#   BRICK: 46.7181
#   ORE: 46.3924
#   SHEEP: 46.0445
#   VP: 36.1709
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(1, 6))")
#   WOOD: 33.2558
#   WHEAT: 33.1728
#   ORE: 31.7304
#   BRICK: 31.5215
#   SHEEP: 31.4618
#   VP: 24.5337
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(3, 4))")
#   WHEAT: 33.8689
#   WOOD: 33.6735
#   BRICK: 31.9889
#   ORE: 31.7106
#   SHEEP: 31.6297
#   VP: 24.7429
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 0, -1), <Color.WHITE: 'WHITE'>, None))")
#   WOOD: 38.2953
#   WHEAT: 38.1252
#   BRICK: 36.2635
#   ORE: 35.6398
#   SHEEP: 35.5162
#   VP: 28.0610
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', None, None, 'BRICK'))")
#   WHEAT: 42.1743
#   WOOD: 42.0761
#   BRICK: 39.6140
#   ORE: 39.5204
#   SHEEP: 39.1217
#   VP: 30.8894
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', None, None, 'WOOD'))")
#   WOOD: 29.5364
#   WHEAT: 29.3920
#   BRICK: 28.0942
#   ORE: 27.6388
#   SHEEP: 27.6307
#   VP: 21.6438
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(7, 8))")
#   WOOD: 31.5763
#   WHEAT: 31.5448
#   BRICK: 29.9400
#   ORE: 29.7897
#   SHEEP: 29.5704
#   VP: 23.2480
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(7, 24))")
#   WOOD: 29.0155
#   WHEAT: 28.8096
#   BRICK: 27.5280
#   ORE: 27.2354
#   SHEEP: 27.0232
#   VP: 21.1139
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 2, 0), None, None))")
#   WHEAT: 33.9248
#   WOOD: 33.7368
#   BRICK: 31.9005
#   SHEEP: 31.8939
#   ORE: 31.8645
#   VP: 25.1239
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -2, 0), <Color.ORANGE: 'ORANGE'>, None))")
#   WOOD: 35.4260
#   WHEAT: 35.0647
#   BRICK: 33.7074
#   SHEEP: 33.3616
#   ORE: 33.0662
#   VP: 25.7536
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, 1, -2), None, None))")
#   WOOD: 33.7544
#   WHEAT: 33.3847
#   BRICK: 32.0236
#   ORE: 31.5408
#   SHEEP: 31.4918
#   VP: 24.7361
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', None, None, 'ORE'))")
#   WOOD: 36.7853
#   WHEAT: 36.7376
#   BRICK: 35.0861
#   SHEEP: 34.4153
#   ORE: 34.4088
#   VP: 27.0678
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=15)")
#   WHEAT: 42.6439
#   WOOD: 42.5969
#   BRICK: 40.3861
#   ORE: 39.9338
#   SHEEP: 39.9331
#   VP: 31.0592
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(3, 12))")
#   WHEAT: 45.6782
#   WOOD: 45.2120
#   ORE: 42.6819
#   BRICK: 42.4915
#   SHEEP: 42.1111
#   VP: 33.1013
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, -1, 1), None, None))")
#   WHEAT: 33.1172
#   WOOD: 32.6258
#   BRICK: 30.9735
#   ORE: 30.9158
#   SHEEP: 30.6054
#   VP: 24.3084
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', 'BRICK', 'ORE'))")
#   WOOD: 43.8804
#   WHEAT: 43.4712
#   BRICK: 41.6177
#   ORE: 41.1910
#   SHEEP: 40.8891
#   VP: 31.9184
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=6)")
#   WOOD: 41.5608
#   WHEAT: 41.2853
#   BRICK: 39.7268
#   SHEEP: 39.0777
#   ORE: 38.5391
#   VP: 30.1133
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', 'BRICK', 'WOOD'))")
#   WOOD: 42.5496
#   WHEAT: 42.1232
#   BRICK: 40.3868
#   SHEEP: 39.6958
#   ORE: 39.5964
#   VP: 30.8504
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=3)")
#   WHEAT: 44.2998
#   WOOD: 44.1129
#   BRICK: 41.9181
#   SHEEP: 41.6908
#   ORE: 41.3518
#   VP: 32.2303
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -2, 1), <Color.ORANGE: 'ORANGE'>, None))")
#   WHEAT: 43.2605
#   WOOD: 43.1899
#   BRICK: 41.5542
#   SHEEP: 40.8024
#   ORE: 40.4240
#   VP: 31.8040
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'WOOD'))")
#   WOOD: 42.8354
#   WHEAT: 42.6971
#   BRICK: 40.9762
#   SHEEP: 40.6585
#   ORE: 40.2547
#   VP: 31.2301
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(11, 12))")
#   WHEAT: 45.2176
#   WOOD: 45.0608
#   ORE: 42.5725
#   BRICK: 42.3915
#   SHEEP: 42.2241
#   VP: 32.9527
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -1, -1), <Color.WHITE: 'WHITE'>, None))")
#   WHEAT: 44.3242
#   WOOD: 43.9456
#   BRICK: 41.5654
#   ORE: 40.9884
#   SHEEP: 40.8166
#   VP: 32.0981
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.PLAY_YEAR_OF_PLENTY: 'PLAY_YEAR_OF_PLENTY'>, value=('ORE', 'ORE'))")
#   WHEAT: 42.7696
#   WOOD: 42.5823
#   BRICK: 40.2456
#   ORE: 39.7288
#   SHEEP: 39.4938
#   VP: 31.2062
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'WOOD'))")
#   WHEAT: 54.6904
#   WOOD: 54.3641
#   BRICK: 51.7616
#   SHEEP: 51.1523
#   ORE: 50.9220
#   VP: 39.5769
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(15, 17))")
#   WHEAT: 42.6035
#   WOOD: 42.0376
#   BRICK: 39.8663
#   ORE: 39.3925
#   SHEEP: 39.2840
#   VP: 30.9548
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('BRICK', 'BRICK', 'BRICK', 'BRICK', 'SHEEP'))")
#   WOOD: 44.3578
#   WHEAT: 44.3286
#   BRICK: 42.2223
#   ORE: 41.6351
#   SHEEP: 41.4536
#   VP: 32.5385
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(39, 41))")
#   WHEAT: 43.7990
#   WOOD: 43.4300
#   BRICK: 41.1661
#   ORE: 40.7895
#   SHEEP: 40.5628
#   VP: 31.9578
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=3)")
#   WOOD: 46.5902
#   WHEAT: 46.2355
#   BRICK: 44.4545
#   SHEEP: 43.7259
#   ORE: 43.3719
#   VP: 33.7903
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=11)")
#   WHEAT: 37.0260
#   WOOD: 36.8607
#   BRICK: 35.1584
#   ORE: 34.8382
#   SHEEP: 34.5958
#   VP: 27.2874
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(17, 18))")
#   WHEAT: 47.1918
#   WOOD: 46.9810
#   ORE: 44.2772
#   BRICK: 44.1829
#   SHEEP: 44.0690
#   VP: 34.3776
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 1, 1), <Color.WHITE: 'WHITE'>, None))")
#   WHEAT: 30.9449
#   WOOD: 30.8465
#   BRICK: 29.4731
#   ORE: 29.0046
#   SHEEP: 28.9837
#   VP: 22.7863
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'BRICK'))")
#   WHEAT: 40.8547
#   WOOD: 40.6759
#   BRICK: 38.6568
#   ORE: 38.0208
#   SHEEP: 37.9466
#   VP: 29.7721
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(27, 28))")
#   WOOD: 44.4704
#   WHEAT: 44.2763
#   ORE: 41.9316
#   BRICK: 41.8166
#   SHEEP: 41.2710
#   VP: 32.3774
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=11)")
#   WOOD: 43.0316
#   WHEAT: 43.0138
#   BRICK: 41.2297
#   SHEEP: 40.2526
#   ORE: 40.2273
#   VP: 31.2984
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=1)")
#   WOOD: 42.1767
#   WHEAT: 42.0585
#   BRICK: 39.6871
#   ORE: 39.3975
#   SHEEP: 39.1575
#   VP: 30.7963
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(0, 1))")
#   WOOD: 47.7336
#   WHEAT: 47.6558
#   BRICK: 45.0062
#   ORE: 44.7173
#   SHEEP: 44.4024
#   VP: 34.9383
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(10, 11))")
#   WOOD: 45.8715
#   WHEAT: 45.8610
#   BRICK: 43.1821
#   ORE: 42.9734
#   SHEEP: 42.6882
#   VP: 33.5122
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=7)")
#   WOOD: 48.9579
#   WHEAT: 48.8617
#   BRICK: 46.0028
#   ORE: 45.8835
#   SHEEP: 45.5051
#   VP: 35.7769
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(6, 7))")
#   WHEAT: 36.5286
#   WOOD: 36.4424
#   BRICK: 34.8287
#   SHEEP: 34.4203
#   ORE: 34.1394
#   VP: 26.8348
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'SHEEP'))")
#   WOOD: 40.3596
#   WHEAT: 40.2987
#   BRICK: 38.4477
#   ORE: 37.8262
#   SHEEP: 37.8157
#   VP: 29.5965
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 2, -1), None, None))")
#   WOOD: 34.3730
#   WHEAT: 34.3430
#   ORE: 32.7026
#   BRICK: 32.4857
#   SHEEP: 32.2207
#   VP: 25.2926
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(9, 10))")
#   WHEAT: 45.7563
#   WOOD: 45.2306
#   BRICK: 42.8751
#   ORE: 42.6034
#   SHEEP: 42.3820
#   VP: 33.2571
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -1, 0), <Color.ORANGE: 'ORANGE'>, None))")
#   WHEAT: 36.8007
#   WOOD: 36.6231
#   BRICK: 34.8140
#   ORE: 34.3226
#   SHEEP: 34.0990
#   VP: 26.9070
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(10, 29))")
#   WHEAT: 40.4465
#   WOOD: 39.8730
#   BRICK: 37.8070
#   ORE: 37.5760
#   SHEEP: 37.1522
#   VP: 29.4675
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.PLAY_ROAD_BUILDING: 'PLAY_ROAD_BUILDING'>, value=None)")
#   WOOD: 32.4688
#   WHEAT: 32.1759
#   BRICK: 30.7407
#   ORE: 30.3221
#   SHEEP: 30.1630
#   VP: 23.5597
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(8, 9))")
#   WHEAT: 42.4195
#   WOOD: 41.9114
#   ORE: 39.5539
#   BRICK: 39.5087
#   SHEEP: 39.1400
#   VP: 30.9947
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -2, 0), None, None))")
#   WHEAT: 28.1586
#   WOOD: 28.0996
#   BRICK: 26.6998
#   ORE: 26.5816
#   SHEEP: 26.4264
#   VP: 20.8364
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(11, 32))")
#   WHEAT: 46.2386
#   WOOD: 45.7408
#   BRICK: 43.2501
#   ORE: 42.9822
#   SHEEP: 42.6493
#   VP: 33.5465
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'BRICK'))")
#   WOOD: 42.5862
#   WHEAT: 42.2232
#   BRICK: 40.2754
#   ORE: 40.1421
#   SHEEP: 39.6029
#   VP: 30.9631
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'WHEAT'))")
#   WOOD: 48.8399
#   WHEAT: 48.8292
#   BRICK: 46.0595
#   ORE: 45.5481
#   SHEEP: 45.4261
#   VP: 35.6612
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -2, 1), None, None))")
#   WHEAT: 33.9302
#   WOOD: 33.6305
#   BRICK: 31.9651
#   ORE: 31.7747
#   SHEEP: 31.6790
#   VP: 25.0450
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(28, 29))")
#   WOOD: 44.2223
#   WHEAT: 44.1932
#   ORE: 41.8042
#   BRICK: 41.7141
#   SHEEP: 41.3147
#   VP: 32.4276
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(27, 28))")
#   WHEAT: 47.2542
#   WOOD: 47.1902
#   BRICK: 44.7884
#   ORE: 44.5362
#   SHEEP: 44.1671
#   VP: 34.5251
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'ORE'))")
#   WOOD: 55.2149
#   WHEAT: 54.8472
#   BRICK: 51.8479
#   ORE: 51.6695
#   SHEEP: 51.2093
#   VP: 40.2687
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(31, 32))")
#   WHEAT: 37.3430
#   WOOD: 37.1581
#   ORE: 35.4842
#   BRICK: 35.0441
#   SHEEP: 34.9194
#   VP: 27.4639
#
# ...
#   VP: 36.7116
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'BRICK'))")
#   WOOD: 57.7409
#   WHEAT: 57.5813
#   BRICK: 54.5854
#   ORE: 53.6455
#   SHEEP: 53.5107
#   VP: 41.8633
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(0, 20))")
#   WHEAT: 51.8633
#   WOOD: 51.4558
#   ORE: 48.5301
#   BRICK: 48.2640
#   SHEEP: 48.1001
#   VP: 37.5396
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(39, 41))")
#   WOOD: 44.3755
#   WHEAT: 44.2507
#   ORE: 41.8605
#   BRICK: 41.8297
#   SHEEP: 41.4077
#   VP: 32.3877
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'BRICK'))")
#   WHEAT: 46.9967
#   WOOD: 46.9562
#   BRICK: 44.9466
#   SHEEP: 44.6173
#   ORE: 44.3980
#   VP: 34.3503
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('SHEEP', 'SHEEP', 'SHEEP', 'SHEEP', 'BRICK'))")
#   WOOD: 45.7879
#   WHEAT: 45.4097
#   BRICK: 43.0688
#   ORE: 42.9646
#   SHEEP: 42.5951
#   VP: 32.9598
#
# Action: ('Action', "Action(color=<Color.BLUE: 'BLUE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(16, 18))")
#   WHEAT: 46.6147
#   WOOD: 46.4415
#   ORE: 43.6754
#   BRICK: 43.6149
#   SHEEP: 43.1890
#   VP: 33.9608
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=12)")
#   WHEAT: 45.4339
#   WOOD: 45.4181
#   BRICK: 42.6673
#   ORE: 42.6071
#   SHEEP: 42.2002
#   VP: 32.9846
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=12)")
#   WOOD: 44.4014
#   WHEAT: 44.2028
#   BRICK: 42.3537
#   SHEEP: 41.8768
#   ORE: 41.5314
#   VP: 32.2020
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(22, 23))")
#   WHEAT: 53.3855
#   WOOD: 53.0572
#   BRICK: 50.2284
#   ORE: 49.7295
#   SHEEP: 49.3475
#   VP: 38.8050
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=2)")
#   WHEAT: 47.5868
#   WOOD: 47.4524
#   BRICK: 45.4753
#   SHEEP: 44.4200
#   ORE: 44.2000
#   VP: 34.5710
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -2, 0), <Color.BLUE: 'BLUE'>, None))")
#   WHEAT: 50.8299
#   WOOD: 50.6591
#   BRICK: 48.0445
#   SHEEP: 47.2999
#   ORE: 46.9965
#   VP: 36.9515
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=31)")
#   WOOD: 45.2674
#   WHEAT: 45.1748
#   BRICK: 42.7297
#   ORE: 42.3230
#   SHEEP: 41.9737
#   VP: 33.1778
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(30, 31))")
#   WOOD: 49.9545
#   WHEAT: 49.6950
#   BRICK: 46.9414
#   ORE: 46.6774
#   SHEEP: 46.3858
#   VP: 36.3825
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(12, 13))")
#   WOOD: 49.9727
#   WHEAT: 49.7021
#   BRICK: 46.9079
#   ORE: 46.7023
#   SHEEP: 46.4825
#   VP: 36.5065
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=4)")
#   WOOD: 48.9640
#   WHEAT: 48.9370
#   BRICK: 46.0958
#   ORE: 45.8776
#   SHEEP: 45.5766
#   VP: 35.8478
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(3, 4))")
#   WOOD: 40.4537
#   WHEAT: 40.2752
#   ORE: 38.2036
#   SHEEP: 38.1741
#   BRICK: 38.1561
#   VP: 29.7180
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 1, 0), <Color.ORANGE: 'ORANGE'>, None))")
#   WHEAT: 40.2891
#   WOOD: 40.2120
#   ORE: 38.4844
#   SHEEP: 38.2070
#   BRICK: 37.8356
#   VP: 29.7990
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 0, 1), <Color.ORANGE: 'ORANGE'>, None))")
#   WOOD: 34.8365
#   WHEAT: 34.6688
#   ORE: 33.0822
#   BRICK: 32.9747
#   SHEEP: 32.6392
#   VP: 25.4384
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(4, 15))")
#   WOOD: 41.0253
#   WHEAT: 40.9304
#   BRICK: 38.9007
#   SHEEP: 38.7655
#   ORE: 38.5294
#   VP: 30.0257
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(4, 5))")
#   WHEAT: 44.5415
#   WOOD: 44.5406
#   BRICK: 42.2762
#   SHEEP: 42.1522
#   ORE: 41.8349
#   VP: 32.7191
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(14, 15))")
#   WOOD: 40.6337
#   WHEAT: 40.6122
#   SHEEP: 38.4427
#   BRICK: 38.4363
#   ORE: 38.2023
#   VP: 29.9124
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=12)")
#   WOOD: 46.4668
#   WHEAT: 46.0085
#   BRICK: 44.3818
#   SHEEP: 43.7912
#   ORE: 43.3902
#   VP: 33.8555
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=4)")
#   WOOD: 44.3111
#   WHEAT: 44.0930
#   BRICK: 42.3201
#   SHEEP: 41.8216
#   ORE: 41.5145
#   VP: 32.2501
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'BRICK'))")
#   WOOD: 40.2686
#   WHEAT: 40.0925
#   BRICK: 38.2807
#   SHEEP: 38.0458
#   ORE: 37.8000
#   VP: 29.3666
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(13, 14))")
#   WHEAT: 40.3199
#   WOOD: 40.0106
#   BRICK: 37.9317
#   SHEEP: 37.8580
#   ORE: 37.7811
#   VP: 29.4074
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -1, 0), <Color.WHITE: 'WHITE'>, None))")
#   WHEAT: 42.3420
#   WOOD: 42.3399
#   BRICK: 40.5281
#   SHEEP: 39.9779
#   ORE: 39.7423
#   VP: 31.1362
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=14)")
#   WHEAT: 44.7041
#   WOOD: 44.4585
#   BRICK: 42.3737
#   ORE: 42.0602
#   SHEEP: 41.9678
#   VP: 32.5946
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'SHEEP'))")
#   WOOD: 48.2110
#   WHEAT: 48.0959
#   BRICK: 45.8072
#   ORE: 45.5952
#   SHEEP: 45.5902
#   VP: 35.2718
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'ORE'))")
#   WOOD: 42.6058
#   WHEAT: 42.3945
#   BRICK: 40.5481
#   SHEEP: 40.4992
#   ORE: 40.3713
#   VP: 31.1676
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-2, 1, 1), <Color.ORANGE: 'ORANGE'>, None))")
#   WHEAT: 44.4199
#   WOOD: 43.8156
#   BRICK: 41.4062
#   ORE: 41.3910
#   SHEEP: 41.3173
#   VP: 32.5026
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(7, 8))")
#   WHEAT: 47.8342
#   WOOD: 47.4879
#   BRICK: 45.0279
#   SHEEP: 44.7801
#   ORE: 44.5411
#   VP: 34.9032
#
# Action: ('Action', "Action(color=<Color.WHITE: 'WHITE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(32, 33))")
#   WHEAT: 50.9562
#   WOOD: 50.6916
#   ORE: 47.7378
#   BRICK: 47.5507
#   SHEEP: 47.3307
#   VP: 36.9401
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(0, 5))")
#   WHEAT: 50.9747
#   WOOD: 50.5218
#   BRICK: 47.5877
#   ORE: 47.5194
#   SHEEP: 47.1856
#   VP: 36.8465
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(13, 34))")
#   WHEAT: 53.0461
#   WOOD: 53.0452
#   BRICK: 49.6161
#   ORE: 49.5908
#   SHEEP: 49.2702
#   VP: 38.4689
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=34)")
#   WHEAT: 46.6288
#   WOOD: 46.5222
#   BRICK: 43.9143
#   SHEEP: 43.6414
#   ORE: 43.6295
#   VP: 33.8850
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=51)")
#   WOOD: 42.9262
#   WHEAT: 42.8046
#   BRICK: 40.6718
#   ORE: 40.1436
#   SHEEP: 39.9259
#   VP: 31.4907
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=11)")
#   WOOD: 43.2766
#   WHEAT: 43.0833
#   BRICK: 40.7684
#   ORE: 40.3270
#   SHEEP: 40.0636
#   VP: 31.6241
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=21)")
#   WOOD: 48.9386
#   WHEAT: 48.7702
#   BRICK: 46.0504
#   ORE: 45.8177
#   SHEEP: 45.4987
#   VP: 35.7771
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(21, 43))")
#   WOOD: 41.6315
#   WHEAT: 41.3709
#   BRICK: 39.3186
#   SHEEP: 39.2636
#   ORE: 39.2207
#   VP: 30.5237
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'ORE'))")
#   WOOD: 39.9512
#   WHEAT: 39.6496
#   BRICK: 37.7863
#   SHEEP: 37.6273
#   ORE: 37.5271
#   VP: 29.0727
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(8, 9))")
#   WHEAT: 48.6997
#   WOOD: 48.3869
#   BRICK: 45.8708
#   SHEEP: 45.3854
#   ORE: 45.3343
#   VP: 35.4229
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((2, -2, 0), <Color.ORANGE: 'ORANGE'>, None))")
#   WHEAT: 40.7447
#   WOOD: 40.2198
#   BRICK: 38.0853
#   SHEEP: 37.7738
#   ORE: 37.7519
#   VP: 29.7745
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'SHEEP'))")
#   WHEAT: 50.8930
#   WOOD: 50.7789
#   BRICK: 47.8499
#   ORE: 47.6666
#   SHEEP: 47.4294
#   VP: 37.1825
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=8)")
#   WOOD: 43.0778
#   WHEAT: 42.9489
#   BRICK: 40.9002
#   SHEEP: 40.4833
#   ORE: 40.2557
#   VP: 31.2623
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(31, 32))")
#   WHEAT: 47.6959
#   WOOD: 47.4737
#   BRICK: 44.9872
#   SHEEP: 44.4664
#   ORE: 44.3225
#   VP: 34.6202
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((1, -2, 1), <Color.ORANGE: 'ORANGE'>, None))")
#   WOOD: 40.0404
#   WHEAT: 39.8532
#   BRICK: 38.1002
#   SHEEP: 37.8198
#   ORE: 37.3695
#   VP: 29.2969
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=51)")
#   WOOD: 44.4244
#   WHEAT: 44.2155
#   BRICK: 42.1963
#   SHEEP: 41.9167
#   ORE: 41.7005
#   VP: 32.5528
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'WHEAT'))")
#   WOOD: 48.3313
#   WHEAT: 48.1912
#   BRICK: 45.9246
#   SHEEP: 45.5709
#   ORE: 45.2504
#   VP: 35.3666
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'WOOD'))")
#   WOOD: 41.4770
#   WHEAT: 41.0116
#   SHEEP: 39.1661
#   ORE: 39.1638
#   BRICK: 39.0165
#   VP: 30.1922
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=11)")
#   WHEAT: 48.6694
#   WOOD: 48.4047
#   BRICK: 46.2165
#   SHEEP: 45.5193
#   ORE: 45.2909
#   VP: 35.5722
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('ORE', 'ORE', 'ORE', 'ORE', 'SHEEP'))")
#   WHEAT: 51.8396
#   WOOD: 51.4001
#   BRICK: 48.8617
#   SHEEP: 47.9735
#   ORE: 47.7393
#   VP: 37.6113
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 2, -2), <Color.RED: 'RED'>, None))")
#   WHEAT: 53.2131
#   WOOD: 52.8429
#   BRICK: 50.0076
#   ORE: 49.7926
#   SHEEP: 49.5655
#   VP: 38.6323
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(22, 23))")
#   WHEAT: 52.1601
#   WOOD: 51.7600
#   BRICK: 49.1070
#   ORE: 48.8108
#   SHEEP: 48.6014
#   VP: 37.9548
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WHEAT', 'WHEAT', 'WHEAT', 'WHEAT', 'SHEEP'))")
#   WOOD: 43.3344
#   WHEAT: 43.2782
#   BRICK: 41.2598
#   SHEEP: 40.9809
#   ORE: 40.7580
#   VP: 31.6455
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'WHEAT'))")
#   WHEAT: 45.8184
#   WOOD: 45.5960
#   BRICK: 43.3475
#   SHEEP: 43.0425
#   ORE: 42.7205
#   VP: 33.2818
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=29)")
#   WHEAT: 48.7981
#   WOOD: 48.6499
#   BRICK: 46.4506
#   SHEEP: 45.7658
#   ORE: 45.5827
#   VP: 35.5871
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, 2, -1), <Color.RED: 'RED'>, None))")
#   WOOD: 51.5144
#   WHEAT: 51.3642
#   BRICK: 48.7321
#   SHEEP: 48.3224
#   ORE: 48.2701
#   VP: 37.6354
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_SETTLEMENT: 'BUILD_SETTLEMENT'>, value=22)")
#   WOOD: 51.4644
#   WHEAT: 51.3800
#   BRICK: 48.5676
#   SHEEP: 48.2053
#   ORE: 48.2035
#   VP: 37.6253
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(19, 21))")
#   WHEAT: 47.6516
#   WOOD: 47.2875
#   BRICK: 44.5462
#   SHEEP: 44.2611
#   ORE: 44.2236
#   VP: 34.6746
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_ROAD: 'BUILD_ROAD'>, value=(43, 44))")
#   WHEAT: 46.1084
#   WOOD: 45.7228
#   BRICK: 43.0579
#   ORE: 42.8511
#   SHEEP: 42.8364
#   VP: 33.5879
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((-1, -1, 2), <Color.ORANGE: 'ORANGE'>, None))")
#   WHEAT: 45.1402
#   WOOD: 44.8869
#   BRICK: 42.3102
#   SHEEP: 42.0811
#   ORE: 42.0351
#   VP: 32.9584
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 0, 0), None, None))")
#   WOOD: 52.3151
#   WHEAT: 52.1254
#   BRICK: 49.2159
#   ORE: 49.1896
#   SHEEP: 49.0104
#   VP: 38.2241
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MOVE_ROBBER: 'MOVE_ROBBER'>, value=((0, 1, -1), <Color.RED: 'RED'>, None))")
#   WHEAT: 55.8796
#   WOOD: 55.7252
#   BRICK: 52.7139
#   SHEEP: 52.0325
#   ORE: 51.8975
#   VP: 40.6223
#
# Action: ('Action', "Action(color=<Color.RED: 'RED'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=21)")
#   WOOD: 41.6030
#   WHEAT: 41.4537
#   BRICK: 39.5319
#   SHEEP: 39.2578
#   ORE: 38.9975
#   VP: 30.3549
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'BRICK'))")
#   WOOD: 50.7730
#   WHEAT: 50.7087
#   BRICK: 47.9868
#   SHEEP: 47.8462
#   ORE: 47.8133
#   VP: 37.0822
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.MARITIME_TRADE: 'MARITIME_TRADE'>, value=('WOOD', 'WOOD', 'WOOD', 'WOOD', 'ORE'))")
#   WHEAT: 53.6506
#   WOOD: 53.2361
#   BRICK: 50.2900
#   ORE: 50.2570
#   SHEEP: 50.0635
#   VP: 38.9872
#
# Action: ('Action', "Action(color=<Color.ORANGE: 'ORANGE'>, action_type=<ActionType.BUILD_CITY: 'BUILD_CITY'>, value=22)")
#   WHEAT: 48.3008
#   WOOD: 48.1671
#   BRICK: 46.0803
#   SHEEP: 45.1794
#   ORE: 45.1232
#   VP: 35.2202

# %%
import matplotlib.pyplot as plt
plt.imshow(model.net[0].weight.detach().numpy(), aspect='auto')
plt.colorbar()
plt.show()
